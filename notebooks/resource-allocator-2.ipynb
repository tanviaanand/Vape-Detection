# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import torch

# %%
# %cd /content/drive/MyDrive/UTA/YoloV7_official_implementation/yolov7/
# Out:
# /content/drive/MyDrive/UTA/YoloV7_official_implementation/yolov7

# %%
#TO CHECK LEARNING RATE FUNCTIONS 

# import argparse
# import logging
# import math
# import os
# import random
# import time
# from copy import deepcopy
# from pathlib import Path
# from threading import Thread

# import numpy as np
# import torch.distributed as dist
# import torch.nn as nn
# import torch.nn.functional as F
# import torch.optim as optim
# import torch.optim.lr_scheduler as lr_scheduler
# import torch.utils.data
# import yaml
# from torch.cuda import amp
# from torch.nn.parallel import DistributedDataParallel as DDP
# from torch.utils.tensorboard import SummaryWriter
# from tqdm import tqdm

# import test  # import test.py to get mAP after each epoch
# from models.experimental import attempt_load
# from models.yolo import Model
# from utils.autoanchor import check_anchors
# from utils.datasets import create_dataloader
# from utils.general import labels_to_class_weights, increment_path, labels_to_image_weights, init_seeds, \
#     fitness, strip_optimizer, get_latest_run, check_dataset, check_file, check_git_status, check_img_size, \
#     check_requirements, print_mutation, set_logging, one_cycle, colorstr
# from utils.google_utils import attempt_download
# from utils.loss import ComputeLoss, ComputeLossOTA
# from utils.plots import plot_images, plot_labels, plot_results, plot_evolution
# from utils.torch_utils import ModelEMA, select_device, intersect_dicts, torch_distributed_zero_first, is_parallel
# from utils.wandb_logging.wandb_utils import WandbLogger, check_wandb_resume
# import pandas as pd
# import matplotlib.pyplot as plt
# l = []

# lr0 = 1e-2
# lrf = 1e-3
# epochs =300
# #lf = lambda x: (1 - x / (epochs - 1)) * (1.0 - lrf) +lrf  # linear
# lf = one_cycle(1, lrf, epochs)  # cosine 1->hyp['lrf']
# model = torch.nn.Linear(2, 1)
# optimizer = torch.optim.SGD(model.parameters(), lr=lr0)
# scheduler = lr_scheduler.LambdaLR(optimizer, lr_lambda=lf)
# for i in range(epochs):
#   l.append((i,scheduler.get_last_lr()[0]))
#   scheduler.step()
# import matplotlib.pyplot as plt

# %matplotlib inline
# df = pd.DataFrame(l, columns =['e', 'lr'])
# df.plot(x='e',y='lr')
# plt.show()

# %%
# !python train_.py --device 0 --batch-size 16 --data data/custom.yaml --img 640 640 --cfg cfg/training/yolov7_custom.yaml --weights yolov7_training.pt --name yoloV7_2_ --hyp data/yoloV7_pe2.yaml --epochs 300 --freeze 50
# Out:
# YOLOR 🚀 v0.1-107-g44d8ab4 torch 1.12.1+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7_custom.yaml', data='data/custom.yaml', device='0', entity=None, epochs=300, evolve=False, exist_ok=False, freeze=[50], global_rank=-1, hyp='data/yoloV7_pe2.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yoloV7_2_', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yoloV7_2_', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='yolov7_training.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python test.py --weights runs/train/yoloV7_2_/weights/best.pt --data data/custom.yaml
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='data/custom.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.65, name='exp', no_trace=False, project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=False, single_cls=False, task='val', verbose=False, weights=['runs/train/yoloV7_2_/weights/best.pt'])
# YOLOR 🚀 v0.1-107-g44d8ab4 torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36492560 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
# ...

# %%
p = 0.83               
r = .774              
print((2*p*r)/(p+r))
# Out:
# 0.8010224438902742

# %%
# !python detect.py --weights runs/train/yoloV7_2_/weights/best.pt  --conf 0.25 --img-size 640 --source ./data/val/images --name yolo2
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='yolo2', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='./data/val/images', update=False, view_img=False, weights=['runs/train/yoloV7_2_/weights/best.pt'])
# YOLOR 🚀 v0.1-107-g44d8ab4 torch 1.12.1+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36492560 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
# ...

# %%
# !python train_.py --device 0 --batch-size 16 --data data/custom.yaml --img 640 640 --cfg cfg/training/yolov7_custom.yaml --weights yolov7_training.pt --name yoloV7_2_with700epochs --hyp data/yoloV7_pe2.yaml --epochs 700 --freeze 50
# Out:
# YOLOR 🚀 v0.1-107-g44d8ab4 torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7_custom.yaml', data='data/custom.yaml', device='0', entity=None, epochs=700, evolve=False, exist_ok=False, freeze=[50], global_rank=-1, hyp='data/yoloV7_pe2.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yoloV7_2_with700epochs', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yoloV7_2_with700epochs', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='yolov7_training.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python test.py --weights runs/train/yoloV7_2_with700epochs/weights/best.pt --data data/custom.yaml --name yoloV7_3_
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='data/custom.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.65, name='yoloV7_3_', no_trace=False, project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=False, single_cls=False, task='val', verbose=False, weights=['runs/train/yoloV7_2_with700epochs/weights/best.pt'])
# YOLOR 🚀 v0.1-107-g44d8ab4 torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36492560 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
# ...

# %%
p = 0.78        
r = 0.76       
print((2*p*r)/(p+r))
# Out:
# 0.7698701298701298

# %%
# !python test.py --weights runs/train/yoloV7_3with300Epochs_2/weights/best.pt --data data/custom.yaml
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='data/custom.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.65, name='exp', no_trace=False, project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=False, single_cls=False, task='val', verbose=False, weights=['runs/train/yoloV7_3with300Epochs_2/weights/best.pt'])
# YOLOR 🚀 v0.1-107-g44d8ab4 torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36492560 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
# ...

# %%
p = .818               
r = 0.726              
print((2*p*r)/(p+r))
# Out:
# 0.7692590673575128

# %%
# !python train_.py --device 0 --batch-size 16 --data data/custom.yaml --img 640 640 --cfg cfg/training/yolov7_custom.yaml --weights yolov7_training.pt --name yoloV7_2_with_multiscale --hyp data/yoloV7_pe2.yaml --epochs 300 --freeze 50 --multi-scale
# Out:
# YOLOR 🚀 v0.1-107-g44d8ab4 torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7_custom.yaml', data='data/custom.yaml', device='0', entity=None, epochs=300, evolve=False, exist_ok=False, freeze=[50], global_rank=-1, hyp='data/yoloV7_pe2.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=True, name='yoloV7_2_with_multiscale', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yoloV7_2_with_multiscale', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='yolov7_training.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python train_.py --device 0 --batch-size 16 --data data/custom.yaml --img 640 640 --cfg cfg/training/yolov7_custom.yaml --weights yolov7_training.pt --name checj_ --hyp data/yoloV7_pe2.yaml --epochs 2 --freeze 50
# Out:
# python3: can't open file 'train_.py': [Errno 2] No such file or directory

# %%
# !python train_.py --device 0 --batch-size 16 --data data/custom.yaml --img 640 640 --cfg cfg/training/yolov7_custom.yaml --weights yolov7_training.pt --name yoloV7_2_with_white_vapes --hyp data/yoloV7_pe2.yaml --epochs 300 --freeze 50
# Out:
# YOLOR 🚀 v0.1-107-g44d8ab4 torch 1.12.1+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7_custom.yaml', data='data/custom.yaml', device='0', entity=None, epochs=300, evolve=False, exist_ok=False, freeze=[50], global_rank=-1, hyp='data/yoloV7_pe2.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yoloV7_2_with_white_vapes', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yoloV7_2_with_white_vapes', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='yolov7_training.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python test.py --weights runs/train/yoloV7_2_with_white_vapes/weights/best.pt --data data/custom.yaml
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='data/custom.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.65, name='exp', no_trace=False, project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=False, single_cls=False, task='val', verbose=False, weights=['runs/train/yoloV7_2_with_white_vapes/weights/best.pt'])
# YOLOR 🚀 v0.1-107-g44d8ab4 torch 1.12.1+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36492560 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
# ...

# %%
# !python test.py --weights runs/train/yoloV7_2_with_white_vapes_withoutFreez_forMoreE/weights/best.pt --data data/custom.yaml

# %% [markdown]
# out of the 340(approx) images that were detcted, I ran inference only for hand (manually checkied that there was no hand) (only two smoke images )
#
#
# Out of them only 190 had hand (so some 340 - 190 images might not have labels)

# %%
# !ls
# Out:
# cfg	    inference	      runs	       train_.py
# data	    LICENSE.md	      scripts	       train_with_modified_lr.py
# deploy	    models	      test.py	       utils
# detect.py   paper	      tools	       yolov7.pt
# export.py   __pycache__       traced_model.pt  yolov7_training_024.pt
# figure	    README.md	      train_aux.py     yolov7_training.pt
# hubconf.py  requirements.txt  train_lr.py

# %%
# !python train_.py --device 0 --batch-size 16 --data data/custom.yaml --img 640 640 --cfg cfg/training/yolov7_custom.yaml --weights yolov7_training.pt --name yoloV7_2_with_white_vapes_from_adi_and_24ydataForRobustness --hyp data/yoloV7_pe2.yaml --epochs 300 --freeze 50
# Out:
# YOLOR 🚀 v0.1-107-g44d8ab4 torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7_custom.yaml', data='data/custom.yaml', device='0', entity=None, epochs=300, evolve=False, exist_ok=False, freeze=[50], global_rank=-1, hyp='data/yoloV7_pe2.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yoloV7_2_with_white_vapes_from_adi_and_24ydataForRobustness', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yoloV7_2_with_white_vapes_from_adi_and_24ydataForRobustness', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='yolov7_training.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python test.py --weights runs/train/yoloV7_2_with_white_vapes_from_adi_and_24ydataForRobustness/weights/best.pt --data data/custom.yaml
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='data/custom.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.65, name='exp', no_trace=False, project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=False, single_cls=False, task='val', verbose=False, weights=['runs/train/yoloV7_2_with_white_vapes_from_adi_and_24ydataForRobustness/weights/best.pt'])
# YOLOR 🚀 v0.1-107-g44d8ab4 torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36492560 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...

# %%
# !python train_.py --device 0 --batch-size 16 --data data/custom.yaml --img 640 640 --cfg cfg/training/yolov7_custom.yaml --weights yolov7_training.pt --name yoloV7_2_ --hyp data/yoloV7_pe2.yaml --epochs 300 --freeze 50

# %%
# !ls /content/drive/MyDrive/UTA/YoloV7_official_implementation/yolov7/data/train/labels
# Out:
# 'Copy of 7050948226492583215_4.txt'     vapenation6755452141336399110_23.txt
# 'Copy of 7054759961670356270_3.txt'     vapenation6755452141336399110_24.txt
# 'Copy of 7054906484345359622_7.txt'     vapenation6755452141336399110_25.txt
# 'Copy of 7055072887895510278_4.txt'     vapenation6755452141336399110_26.txt
# 'Copy of 7055072887895510278_7.txt'     vapenation6755452141336399110_27.txt
# 'Copy of 7055072887895510278_8.txt'     vapenation6755452141336399110_35.txt
# 'Copy of 7055072887895510278_9.txt'     vapenation6760292307339136262_0.txt
# 'Copy of 7057238672818572591_1.txt'     vapenation6760292307339136262_1.txt
# 'Copy of 7057238672818572591_3.txt'     vapenation6760292307339136262_2.txt
# 'Copy of 7057238672818572591_5.txt'     vapenation6760292307339136262_4.txt
# 'Copy of 7057238672818572591_6.txt'     vapenation6760292307339136262_7.txt
# 'Copy of 7057238672818572591_8.txt'     vapenation6760692704084069638_11.txt
# ...

# %%
# !python train_.py --device 0 --batch-size 16 -- data data/custom.yaml --img 640 640 --cfg cfg/training/yolov7_custom.yaml --weights yolov7_training.pt --name yoloV7_3_ --hyp data/yoloV7_pe2.yaml --epochs 300 --freeze 50
# Out:
# YOLOR 🚀 v0.1-107-g44d8ab4 torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7_custom.yaml', data='data/custom.yaml', device='0', entity=None, epochs=300, evolve=False, exist_ok=False, freeze=[50], global_rank=-1, hyp='data/yoloV7_pe2.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yoloV7_3_', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yoloV7_3_2', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='yolov7_training.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...
