# %% [markdown]
# Mount your drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Move into the folder containing the yolo_v7 repo (https://github.com/WongKinYiu/yolov7)

# %%
# %cd /content/drive/MyDrive/UTA/YoloV7_official_implementation/yolov7/

# %% [markdown]
# The following line uses the model with fine-tuned weights stored in runs/train/yoloV7_3_2/weights/best.pt
#
# Bounding boxes with a minimum confidence of 60% are drawn (specified by --conf flag)
#
# Please store the data you would like to run inference on in the ./data folder and mention the path under the --source flag

# %%
# !python detect.py --weights runs/train/yoloV7_3_2/weights/best.pt --conf 0.6 --img-size 640 --source ./data/val/images --name Run_inference

# %% [markdown]
# The images will be stored in a folder named Run_inference under the ./runs folder
